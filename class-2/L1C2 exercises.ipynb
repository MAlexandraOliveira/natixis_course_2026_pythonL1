# %% [markdown]
# # 🐍 Python Level 1 - Introductory course
# ## Class 2 — Data Structures
# ### 📝 Practice Exercises
#
# **Python instructor - Alexandra Oliveira**
#
# ---
#
# <div style="display:inline-flex; align-items:center; gap:28px; background:#FFFFFF; color:#1D1D1B; padding:10px 14px; border-radius:8px; margin-bottom:8px;"><img src="data:image/png;base64,..." alt="Natixis" height="52" style="object-fit:contain;"/><img src="data:image/png;base64,..." alt="Porto Executive Academy" height="62" style="object-fit:contain;"/></div>
#
# ---

# %% [markdown]
# ---
#
# Work through the sections in order — the difficulty increases as you go.
#
# | Section | Difficulty | Topics |
# |---------|------------|--------|
# | A | 🟢 Warm-up | lists and tuples |
# | B | 🟡 Core practice | sets and dictionaries |
# | C | 🟠 Applied | combining structures |
# | D | 🔴 Challenge | complete small programs |
#
# > 💡 **Tip:** everything you need is in the exposition notebook. If you get stuck, look back at
# > the section with the same topic.
#
# > 💡 A **set** has no order of its own, so printing one can put the values in any order. When
# > an exercise asks you to print a set, wrap it in `sorted(...)` — that is why the expected
# > output below shows square brackets for those.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Run this cell first, to check everything works.

# %%
print("Setup complete - let's practise!")

# %% [markdown]
# ---
# ## 🟢 Section A — Warm-up
# ### Lists and tuples
#
# > 🕐 Estimated time: 15 min

# %% [markdown]
# ### Exercise A1 — Build a list
#
# Create a list called `cities` holding `"Porto"`, `"Lisbon"`, `"Faro"`, `"Braga"`.
#
# Print, on four lines: the whole list, how many items it has, the **first** city, and the
# **last** city.
#
# Expected output:
# ```
# ['Porto', 'Lisbon', 'Faro', 'Braga']
# 4
# Porto
# Braga
# ```
#
# > 💡 Get the last item without counting: `cities[-1]`.

# %%
# A1

# %% [markdown]
# ### Exercise A2 — Slicing
#
# Using the same list, print three slices: the **first two** cities, the **last two**, and
# the two in the **middle** (index 1 and 2).
#
# Expected output:
# ```
# ['Porto', 'Lisbon']
# ['Faro', 'Braga']
# ['Lisbon', 'Faro']
# ```

# %%
# A2
cities = ["Porto", "Lisbon", "Faro", "Braga"]

# %% [markdown]
# ### Exercise A3 — Change a list
#
# Starting from the list below, do these three things and **print the list after each one**:
#
# 1. Add `"Braga"` to the end
# 2. Replace the item at index `1` with `"Coimbra"`
# 3. Remove `"Faro"`
#
# Expected output:
# ```
# ['Porto', 'Lisbon', 'Faro', 'Braga']
# ['Porto', 'Coimbra', 'Faro', 'Braga']
# ['Porto', 'Coimbra', 'Braga']
# ```

# %%
# A3
cities = ["Porto", "Lisbon", "Faro"]

# %% [markdown]
# ### Exercise A4 — A tuple that cannot change
#
# Create a tuple `temperature_range` holding the lowest and highest temperature of the week:
# `12.5` and `27.0`.
#
# Print the tuple, then read both values out of it and print:
#
# ```
# (12.5, 27.0)
# Temperatures run from 12.5 to 27.0 degrees
# ```
#
# > 💡 `{value:.1f}` shows one decimal place.

# %%
# A4

# %% [markdown]
# ---
# ## 🟡 Section B — Core practice
# ### Sets and dictionaries
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise B1 — Unique values
#
# The list below has repeats.
#
# 1. Turn it into a set and print **how many** different teams there are
# 2. Add `"Legal"`, remove `"Risk"`, then print the set **sorted**
# 3. Print whether `"Ops"` is still in the set
#
# Expected output:
# ```
# 3
# ['Finance', 'Legal', 'Ops']
# True
# ```

# %%
# B1
teams = ["Ops", "Risk", "Ops", "Finance", "Risk", "Ops"]

# %% [markdown]
# ### Exercise B2 — Compare two sets
#
# Two sets hold the cities delivered to on Monday and on Tuesday. Print, each one **sorted**:
#
# 1. Every city across both days
# 2. The cities delivered to on **both** days
# 3. The cities delivered to on **Monday only**
#
# Expected output:
# ```
# ['Braga', 'Lisbon', 'Porto']
# ['Lisbon']
# ['Porto']
# ```

# %%
# B2
monday = {"Porto", "Lisbon"}
tuesday = {"Lisbon", "Braga"}

# %% [markdown]
# ### Exercise B3 — A record as a dictionary
#
# Using the dictionary below:
#
# 1. Print the title
# 2. Print the number of pages, using `.get()` with a fallback of `"unknown"` — the key is not
#    there yet, and your program must not stop
# 3. Change `year` to `1966`, add `pages` with the value `412`, and remove `author`
# 4. Print the dictionary and how many pairs it now has
#
# Expected output:
# ```
# Dune
# unknown
# {'title': 'Dune', 'year': 1966, 'pages': 412}
# 3
# ```

# %%
# B3
book = {"title": "Dune", "author": "Frank Herbert", "year": 1965}

# %% [markdown]
# ### Exercise B4 — Go through a dictionary
#
# Loop over the dictionary below and print each pair as `key: value`, one per line. Then print
# just the keys, as a list.
#
# Expected output:
# ```
# title: Dune
# year: 1965
# pages: 412
# ['title', 'year', 'pages']
# ```
#
# > 💡 `.items()` gives you the key and the value together. `list(book.keys())` turns the keys
# > into a printable list.

# %%
# B4
book = {"title": "Dune", "year": 1965, "pages": 412}

# %% [markdown]
# ---
# ## 🟠 Section C — Applied
# ### Combining structures
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise C1 — Count the votes
#
# Each entry below is one vote for a city. Build a dictionary that maps each city to **how many
# votes it got**, then print it.
#
# Expected output:
# ```
# {'Porto': 3, 'Lisbon': 2, 'Faro': 1}
# ```
#
# > 💡 Start with an empty dictionary, `counts = {}`. For each city, check `if city in counts`:
# > if it is, add 1 to what is already there; if it is not, start it at 1.

# %%
# C1
votes = ["Porto", "Lisbon", "Porto", "Faro", "Porto", "Lisbon"]

# %% [markdown]
# ### Exercise C2 — A list inside a dictionary
#
# The dictionary below holds a student's name and a **list** of their grades. Print a small
# summary: how many grades, the total, the average rounded to 2 decimals, the best and the worst.
#
# Expected output:
# ```
# Student : Ana
# Grades  : 4
# Total   : 62
# Average : 15.5
# Best    : 19
# Worst   : 12
# ```
#
# > 💡 `student["grades"]` **is** a list, so `sum()`, `len()`, `min()` and `max()` all work on it
# > directly.

# %%
# C2
student = {"name": "Ana", "grades": [14, 17, 12, 19]}

# %% [markdown]
# ### Exercise C3 — Filter a list of dictionaries
#
# Go through the products below and print the ones costing **less than 5.00 EUR**, with the name
# padded to 8 characters and the price right-aligned in 6. Then print how many there were.
#
# Expected output:
# ```
# Tea       4.20 EUR
# Sugar     2.10 EUR
# Milk      1.15 EUR
# Cheap products: 3
# ```
#
# > 💡 The line is `f"{product['name']:<8}{product['price']:>6.2f} EUR"`. Note the **single**
# > quotes inside the f-string's double quotes.

# %%
# C3
products = [
    {"name": "Coffee", "price": 8.50},
    {"name": "Tea",    "price": 4.20},
    {"name": "Sugar",  "price": 2.10},
    {"name": "Milk",   "price": 1.15},
]

# %% [markdown]
# ---
# ## 🔴 Section D — Challenge
# ### Complete small programs
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise D1 — Group the orders by city
#
# Each order below is a dictionary. Build a report grouped **by city**:
#
# 1. Make a dictionary of **city → list of the order totals** for that city
# 2. Print a line per city — city padded to 10, total right-aligned in 8 with 2 decimals, and
#    the number of orders. Go through the cities in **alphabetical** order
# 3. Print how many cities there were, and the grand total
#
# Expected output:
# ```
# ORDERS BY CITY
# --------------------------------------
# Faro          8.75 EUR  (orders: 1)
# Lisbon       27.75 EUR  (orders: 2)
# Porto        64.00 EUR  (orders: 2)
# --------------------------------------
# Cities      : 3
# Grand total : 100.50 EUR
# ```
#
# > 💡 This is the grouping pattern from section 7 of the exposition, keyed on the city instead
# > of the customer. `sorted(by_city)` loops the keys in alphabetical order. The separator is
# > `"-" * 38`.

# %%
# D1
orders = [
    {"customer": "Ana",   "city": "Porto",  "total": 24.00},
    {"customer": "Bruno", "city": "Lisbon", "total": 15.50},
    {"customer": "Clara", "city": "Porto",  "total": 40.00},
    {"customer": "Diogo", "city": "Faro",   "total":  8.75},
    {"customer": "Eva",   "city": "Lisbon", "total": 12.25},
]

# %% [markdown]
# ### Exercise D2 — Stock report
#
# Here each value in the dictionary is **itself a dictionary**, holding a price and a quantity.
#
# Write a stock report that:
#
# 1. **Skips** any product with a quantity of `0` — collect its name in an `out_of_stock` list
#    and move on to the next product, using `continue`
# 2. For every other product, calculates `price * quantity` and adds it to a running total
# 3. Prints a line per product, and marks it `LOW` when the quantity is under 5
# 4. At the end prints the total value, how many products are low, and the out-of-stock names
#    sorted
#
# Expected output:
# ```
# STOCK REPORT
# ----------------------------------------
# Coffee    12 x  8.50 =  102.00 EUR
# Sugar      3 x  2.10 =    6.30 EUR  LOW
# Milk      40 x  1.15 =   46.00 EUR
# ----------------------------------------
# Total value  : 154.30 EUR
# Low stock    : 1
# Out of stock : ['Tea']
# ```
#
# > 💡 `details["quantity"]` reaches inside the inner dictionary. The line is
# > `f"{name:<8}{quantity:>4} x {details['price']:>5.2f} = {value:>7.2f} EUR"` — build it into a
# > variable first, then add `"  LOW"` to it only when needed. The separator is `"-" * 40`.

# %%
# D2
stock = {
    "Coffee": {"price": 8.50, "quantity": 12},
    "Tea":    {"price": 4.20, "quantity": 0},
    "Sugar":  {"price": 2.10, "quantity": 3},
    "Milk":   {"price": 1.15, "quantity": 40},
}

# %% [markdown]
# ---
#
# ### 🎉 Well done!
#
# You have now practised every concept from Class 2:
#
# | | Concept | Exercises |
# |-|---------|----------|
# | ✅ | Lists, indexing, slicing | A1, A2 |
# | ✅ | Changing a list | A3 |
# | ✅ | Tuples | A4 |
# | ✅ | Sets and unique values | B1 |
# | ✅ | Comparing sets | B2 |
# | ✅ | Dictionaries, `.get()` | B3 |
# | ✅ | `.items()`, `.keys()` | B4 |
# | ✅ | Counting into a dict | C1 |
# | ✅ | Structures inside structures | C2, D2 |
# | ✅ | A list of dicts | C3, D1 |
# | ✅ | `sum`, `min`, `max`, `sorted` | C2, D1, D2 |
# | ✅ | Complete programs | D1, D2 |
#
# ➡️ The solutions notebook will be shared after the class. Try everything first — the point is
# the attempt, not the answer.
