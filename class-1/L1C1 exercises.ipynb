# %% [markdown]
# # 🐍 Python Level 1 - Introductory course
# ## Class 1 — Python Basics
# ### 📝 Practice Exercises
#
# **Python instructor - Alexandra Oliveira**
#
# ---
#
# <div style="display:inline-flex; align-items:center; gap:28px; background:#FFFFFF; color:#1D1D1B; padding:10px 14px; border-radius:8px; margin-bottom:8px;"><img src="data:image/png;base64,..." alt="Natixis" height="52" style="object-fit:contain;"/><img src="data:image/png;base64,..." alt="Porto Executive Academy" height="62" style="object-fit:contain;"/></div>
#
# ---

# %% [markdown]
# ---
#
# Work through the sections in order — the difficulty increases as you go.
#
# | Section | Difficulty | Topics |
# |---------|------------|--------|
# | A | 🟢 Warm-up | `print`, variables, types |
# | B | 🟡 Core practice | operators, casting, f-strings |
# | C | 🟠 Applied | conditions and loops |
# | D | 🔴 Challenge | complete small programs |
#
# > 💡 **Tip:** everything you need is in the exposition notebook. If you get stuck, look back
# > at the section with the same topic — don't search the internet yet.
#
# > 💡 Run each cell with `Shift+Enter`. If a cell gives an error, read the **last line** of
# > the message first: it usually tells you exactly what is wrong.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Run this cell first, to check everything works.

# %%
print("Setup complete - let's write some Python!")

# %% [markdown]
# ---
# ## 🟢 Section A — Warm-up
# ### `print`, variables, data types
#
# > 🕐 Estimated time: 15 min

# %% [markdown]
# ### Exercise A1 — Three lines
#
# Print exactly these three lines:
#
# ```
# Hello, Python!
# I work at Natixis.
# Today I am learning to code.
# ```

# %%
# A1

# %% [markdown]
# ### Exercise A2 — Your first variables
#
# Create these four variables and print each one with a label.
#
# | Variable | Value |
# |----------|-------|
# | `course_name` | `"Python Level 1"` |
# | `num_classes` | `4` |
# | `hours_per_class` | `3.0` |
# | `is_beginner_friendly` | `True` |
#
# Expected output:
# ```
# Course: Python Level 1
# Classes: 4
# Hours per class: 3.0
# Beginner friendly: True
# ```

# %%
# A2

# %% [markdown]
# ### Exercise A3 — Type inspector
#
# For each variable below, print its **value** and its **type** on the same line.
#
# Expected output (first line shown):
# ```
# Lisbon <class 'str'>
# ```

# %%
# A3
city = "Lisbon"
population = 545000
area_km2 = 100.05
is_capital = True
districts = ["Alfama", "Belem", "Chiado"]

# Print the value and the type of each one

# %% [markdown]
# ### Exercise A4 — Ask a question
#
# Ask the user for their first name using `input()`, then greet them.
#
# If the user types `Marta`, the output should be:
# ```
# Welcome to Python Level 1, Marta!
# ```

# %%
# A4

# %% [markdown]
# ---
# ## 🟡 Section B — Core practice
# ### Operators, casting, f-strings
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise B1 — Packing boxes
#
# A warehouse has `250` items to pack. Each box holds `12` items.
#
# Using `//` and `%`, calculate and print:
#
# 1. How many **full boxes** they can pack
# 2. How many items are **left over**
#
# Expected output:
# ```
# Full boxes: 20
# Items left over: 10
# ```

# %%
# B1
total_items = 250
box_capacity = 12

# %% [markdown]
# ### Exercise B2 — Casting practice
#
# The two values below are **text** (as if someone had typed them). Cast them to numbers,
# then calculate the total cost.
#
# Print the result rounded to 2 decimals, formatted with a thousands separator.
#
# Expected output:
# ```
# Total cost: 3,748.75
# ```

# %%
# B2
quantity_text = "125"
unit_price_text = "29.99"

# %% [markdown]
# ### Exercise B3 — Build a sentence with an f-string
#
# Using the variables below and **one** f-string, print exactly:
#
# ```
# Order ORD-3312: 8 units at 15.50 EUR each = 124.00 EUR
# ```
#
# > 💡 `{value:.2f}` gives two decimals.

# %%
# B3
order_id = "ORD-3312"
units = 8
unit_price = 15.50

# %% [markdown]
# ### Exercise B4 — True or False?
#
# Using the variables below, write an expression for each question and print its result.
#
# | # | Question | Expected |
# |---|----------|----------|
# | 1 | Is the score above the pass mark? | `True` |
# | 2 | Did the student pass? (above pass mark **and** attended) | `True` |
# | 3 | Is the score a perfect 100? | `False` |
# | 4 | Is `"Chemistry"` **not** in the subject list? | `True` |

# %%
# B4
score = 82
pass_mark = 75
attended = True
subjects = ["Maths", "Physics", "Biology"]

# 1.

# 2.

# 3.

# 4.

# %% [markdown]
# ---
# ## 🟠 Section C — Applied
# ### Conditions and loops
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise C1 — Grade classifier
#
# Write an `if` / `elif` / `else` block that prints a grade for `score`, using this scale:
#
# | Score | Grade |
# |-------|-------|
# | 90 or more | `Excellent` |
# | 75 to 89 | `Good` |
# | 50 to 74 | `Pass` |
# | below 50 | `Fail` |
#
# With `score = 82`, the expected output is:
# ```
# Score 82 -> Good
# ```
#
# Then change `score` a few times and re-run, to check every branch works.

# %%
# C1
score = 82

# %% [markdown]
# ### Exercise C2 — Countdown with a `break`
#
# Write a `while` loop that:
#
# 1. Starts at `attempt = 0`
# 2. Each time round: add 1 to `attempt`, then print `Attempt N of 5`
# 3. When `attempt` reaches `3`, print `Connected!` and leave the loop with `break`
# 4. After the loop, print `Attempts used: 3`
#
# Expected output:
# ```
# Attempt 1 of 5
# Attempt 2 of 5
# Attempt 3 of 5
# Connected!
# Attempts used: 3
# ```

# %%
# C2

# %% [markdown]
# ### Exercise C3 — Count the long words
#
# Loop over the list below and:
#
# 1. Print each city with its position, starting at 1 — e.g. `1. Porto`
# 2. Count how many city names are longer than 5 characters, using `+=`
# 3. After the loop, print `Names longer than 5 characters: 3`
#
# > 💡 You have not learned `enumerate()` yet — keep your own counter variable and add 1 to it
# > each time round the loop.

# %%
# C3
cities = ["Porto", "Coimbra", "Lisbon", "Faro", "Guimaraes"]

# %% [markdown]
# ---
# ## 🔴 Section D — Challenge
# ### Complete small programs
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise D1 — Weekly temperatures
#
# The list below holds one temperature reading per day.
#
# Write a program that:
#
# 1. Calculates and prints the **average**, rounded to 1 decimal
#    *(add the values up in a loop with `+=`, then divide by `len()`)*
# 2. Counts and prints how many days were **above** that average
# 3. Prints the **warmest** day's temperature
#    *(keep a `warmest` variable and update it whenever you find something bigger)*
#
# Expected output:
# ```
# Average: 21.6
# Days above average: 3
# Warmest: 26.4
# ```

# %%
# D1
temperatures = [18.5, 22.1, 26.4, 19.0, 23.8, 20.2, 21.2]

# %% [markdown]
# ### Exercise D2 — Shopping basket receipt
#
# Each item in the basket is a small list: `[name, unit_price, quantity]`.
#
# Write a program that prints a receipt and a summary:
#
# 1. An item with a quantity of `0` is out of stock. Print that it was skipped and move on to
#    the next item using `continue` — it must not affect any of the totals
# 2. For every other item, print the name, the quantity, and the **line total**
#    (`unit_price * quantity`), with 2 decimals
# 3. Add every line total into a `basket_total`, using `+=`
# 4. Count how many lines total **more than 20.00**
# 5. At the end, print the basket total and that count
# 6. If the basket total is over `50.00`, print `Free delivery!`; otherwise print
#    `Add more for free delivery`
#
# Expected output:
# ```
# Coffee          x 2 =  17.00
# Olive oil       x 1 =   8.75
# Tea             out of stock - skipped
# Rice            x 4 =  26.00
# Chocolate       x 3 =   7.50
# --------------------------------
# Basket total: 59.25
# Lines over 20.00: 1
# Free delivery!
# ```
#
# > 💡 `f"{name:<15}"` pads text to 15 characters so the columns line up.
# > `f"{value:>6.2f}"` right-aligns a number in 6 characters with 2 decimals.

# %%
# D2
basket = [
    ["Coffee", 8.50, 2],
    ["Olive oil", 8.75, 1],
    ["Tea", 4.20, 0],
    ["Rice", 6.50, 4],
    ["Chocolate", 2.50, 3],
]

# %% [markdown]
# ---
#
# ### 🎉 Well done!
#
# You have now practised every concept from Class 1:
#
# | | Concept | Exercises |
# |-|---------|----------|
# | ✅ | `print`, variables | A1, A2 |
# | ✅ | Data types, `type()` | A3 |
# | ✅ | `input()` | A4 |
# | ✅ | Arithmetic operators | B1 |
# | ✅ | Casting | B2 |
# | ✅ | f-strings | B3, D2 |
# | ✅ | Comparison, logical, `not in` | B4 |
# | ✅ | `if` / `elif` / `else` | C1, D2 |
# | ✅ | `while` and `break` | C2 |
# | ✅ | `for` loops and `+=` | C3, D1, D2 |
# | ✅ | `continue` | D2 |
# | ✅ | Complete programs | D1, D2 |
#
# ➡️ The solutions notebook will be shared after the class. Try everything first — the point
# is the attempt, not the answer.
